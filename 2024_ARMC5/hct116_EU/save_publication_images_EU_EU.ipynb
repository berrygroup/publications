# %%
import os
import glob
import numpy as np
import mahotas as mh
import pandas as pd

from pathlib import Path
from aicsimageio import AICSImage, readers
from blimp.preprocessing.illumination_correction import IlluminationCorrection

from PIL import Image
from matplotlib import cm

data_dir = "/srv/scratch/berrylab/z3532965/NikonSpinningDisk/ARMC5_KD_EU/240628_ARMC5_EU/Cycle2_EU"
image_dir = os.path.join(data_dir,"20240701_175159_151/OME-TIFF-MIP")
label_image_dir = os.path.join(data_dir,"20240701_175159_151/SEGMENTATION")

ana_dir = "/srv/scratch/z3532965/src/publications/2024_ARMC5/hct116_EU"
illum_corr_file = "/srv/scratch/berrylab/z3532965/NikonSpinningDisk/ARMC5_KD_EU/ILLUMCORR/illumination_correction.pkl"
# Out:
# 25-Jul-24 15:35:00 - bfio.backends - WARNING  - Java backend is not available. This could be due to a missing dependency (jpype).

# %%
def create_overlay_image_plot(
        channel_image, label_image,
        color='rgb(255, 191, 0)', thin=False):

    # threshold label_image and generate outlines
    label_image = np.array(label_image)
    if (thin):
        outlines = mh.labeled.borders(label_image) * 255
    else:
        outlines = mh.morph.dilate(mh.labeled.borders(label_image)) * 255
    overlay = Image.fromarray(np.uint8(outlines))
    outlines_transparent = Image.new(
        mode='RGBA', size=outlines.shape[::-1], color=(0, 0, 0, 0)
    )

    channel_image = channel_image.convert("RGBA")
    outlines_transparent.paste(channel_image, (0,0))
    outlines_transparent.paste(overlay, (0,0), mask=overlay)

    return outlines_transparent

# %% [markdown]
# ## Load metadata
# We have a csv file of the plate layout that includes information on antibody staining

# %%
import re

plate_layout = pd.read_csv(os.path.join(ana_dir,"METADATA","240628_ARMC5KD_EU.csv"))
plate_layout.columns

def pad_well_names(name):
    return re.sub(r'(\D)(\d)$', r'\g<1>0\2', name)

# Apply the function to the DataFrame column in place
plate_layout['well_name'] = plate_layout['WELL'].apply(lambda x: pad_well_names(x))

# %% [markdown]
# ## Apply illumination correction
#
# Load illumination correction object

# %%
illumination_correction = IlluminationCorrection(from_file=illum_corr_file)

# %% [markdown]
# ## Join image metadata and plate layout

# %%
image_metadata_files = glob.glob(os.path.join(image_dir,"*.csv"))
image_metadata = pd.concat((pd.read_csv(f) for f in image_metadata_files), ignore_index=True)
image_metadata['well_name'] = image_metadata['filename_ome_tiff'].str.extract(r'Well([A-Z]\d{2})_Channel')
image_metadata.columns
# Out:
# Index(['n_pixels_y', 'n_pixels_x', 'objective_name', 'pixel_size_microns',
#        'field_id', 'timepoint_id', 'filename_ome_tiff', 'acquisition_time_rel',
#        'stage_y_abs', 'stage_x_abs', 'stage_z_n', 'acquisition_time_abs',
#        'standard_field_id', 'metadata_string_acquisition_0',
#        'metadata_string_acquisition_1', 'well_name'],
#       dtype='object')

# %%
image_metadata_annotated = image_metadata.merge(plate_layout,left_on="well_name", right_on="well_name")

# %%
image_metadata_annotated.query(
    "CELL == 'HCT116' and field_id == 1 and EU == '100 µM'")
# Out:
#      n_pixels_y  n_pixels_x          objective_name  pixel_size_microns  \
# 0          2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 9          2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 18         2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 36         2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 72         2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 81         2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 90         2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 99         2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 108        2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 117        2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 153        2304        2304  Plan Apo VC 20x DIC N2            0.324272
# 162        2304        2304  Plan Apo VC 20x DIC N2            0.324272
#
#      field_id  timepoint_id                             filename_ome_tiff  \
# 0           1             0  WellC06_Channel647,405_Seq0003_0001.ome.tiff
# 9           1             0  WellC08_Channel647,405_Seq0005_0001.ome.tiff
# 18          1             0  WellC04_Channel647,405_Seq0001_0001.ome.tiff
# 36          1             0  WellC07_Channel647,405_Seq0004_0001.ome.tiff
# 72          1             0  WellC03_Channel647,405_Seq0000_0001.ome.tiff
# 81          1             0  WellD06_Channel647,405_Seq0008_0001.ome.tiff
# 90          1             0  WellD08_Channel647,405_Seq0006_0001.ome.tiff
# 99          1             0  WellD05_Channel647,405_Seq0009_0001.ome.tiff
# 108         1             0  WellD07_Channel647,405_Seq0007_0001.ome.tiff
# 117         1             0  WellC05_Channel647,405_Seq0002_0001.ome.tiff
# 153         1             0  WellD03_Channel647,405_Seq0011_0001.ome.tiff
# 162         1             0  WellD04_Channel647,405_Seq0010_0001.ome.tiff
#
#      acquisition_time_rel   stage_y_abs   stage_x_abs  ...  standard_field_id  \
# 0              518.046081 -25615.342857  29762.900000  ...                  3
# 9              851.028722 -25622.785714  20755.500000  ...                  3
# 18             184.569163 -25608.028571  38770.600000  ...                  3
# 36             684.005956 -25619.000000  25259.200000  ...                  3
# 72              16.155628 -25604.500000  43274.542857  ...                  3
# 81            1352.436107 -21123.457143  29719.200000  ...                  3
# 90            1018.535915 -21131.042857  20711.700000  ...                  3
# 99            1518.867715 -21120.000000  34223.100000  ...                  3
# 108           1186.040595 -21127.300000  25215.500000  ...                  3
# 117            351.701741 -25611.700000  34266.800000  ...                  3
# 153           1851.604149 -21112.600000  43230.600000  ...                  3
# 162           1685.149926 -21116.300000  38726.800000  ...                  3
#
#                          metadata_string_acquisition_0  \
# 0    Plane #1:\n Name: 647\n Component Count: 1\n M...
# 9    Plane #1:\n Name: 647\n Component Count: 1\n M...
# 18   Plane #1:\n Name: 647\n Component Count: 1\n M...
# 36   Plane #1:\n Name: 647\n Component Count: 1\n M...
# 72   Plane #1:\n Name: 647\n Component Count: 1\n M...
# 81   Plane #1:\n Name: 647\n Component Count: 1\n M...
# 90   Plane #1:\n Name: 647\n Component Count: 1\n M...
# 99   Plane #1:\n Name: 647\n Component Count: 1\n M...
# 108  Plane #1:\n Name: 647\n Component Count: 1\n M...
# 117  Plane #1:\n Name: 647\n Component Count: 1\n M...
# 153  Plane #1:\n Name: 647\n Component Count: 1\n M...
# 162  Plane #1:\n Name: 647\n Component Count: 1\n M...
#
#                          metadata_string_acquisition_1 well_name WELL    CELL  \
# 0    Plane #2:\n Name: 405\n Component Count: 1\n M...       C06   C6  HCT116
# 9    Plane #2:\n Name: 405\n Component Count: 1\n M...       C08   C8  HCT116
# 18   Plane #2:\n Name: 405\n Component Count: 1\n M...       C04   C4  HCT116
# 36   Plane #2:\n Name: 405\n Component Count: 1\n M...       C07   C7  HCT116
# 72   Plane #2:\n Name: 405\n Component Count: 1\n M...       C03   C3  HCT116
# 81   Plane #2:\n Name: 405\n Component Count: 1\n M...       D06   D6  HCT116
# 90   Plane #2:\n Name: 405\n Component Count: 1\n M...       D08   D8  HCT116
# 99   Plane #2:\n Name: 405\n Component Count: 1\n M...       D05   D5  HCT116
# 108  Plane #2:\n Name: 405\n Component Count: 1\n M...       D07   D7  HCT116
# 117  Plane #2:\n Name: 405\n Component Count: 1\n M...       C05   C5  HCT116
# 153  Plane #2:\n Name: 405\n Component Count: 1\n M...       D03   D3  HCT116
# 162  Plane #2:\n Name: 405\n Component Count: 1\n M...       D04   D4  HCT116
#
#           SIRNA       PRIMARY            SECONDARY      EU
# 0    ARMC5 pool  Total Pol II       Anti-mouse 561  100 µM
# 9    ARMC5 pool  Total Pol II       Anti-mouse 561  100 µM
# 18   ARMC5 pool  Total Pol II       Anti-mouse 561  100 µM
# 36     Scramble  Total Pol II       Anti-mouse 561  100 µM
# 72     Scramble  Total Pol II  Anti-mouse Alexa561  100 µM
# 81     Scramble  Total Pol II       Anti-mouse 561  100 µM
# 90     Scramble  Total Pol II       Anti-mouse 561  100 µM
# 99   ARMC5 pool  Total Pol II       Anti-mouse 561  100 µM
# 108  ARMC5 pool  Total Pol II       Anti-mouse 561  100 µM
# 117    Scramble  Total Pol II       Anti-mouse 561  100 µM
# 153  ARMC5 pool  Total Pol II       Anti-mouse 561  100 µM
# 162    Scramble  Total Pol II       Anti-mouse 561  100 µM
#
# [12 rows x 22 columns]

# %% [markdown]
# ## Save Examples

# %%
example_images = image_metadata_annotated.query("field_id == 4")[['filename_ome_tiff','CELL','SIRNA','EU','well_name']]
example_images['new_filename'] = example_images['CELL'] + '_' + example_images['SIRNA'] + '_' + example_images['EU'] + '_' + example_images['well_name'] + '.png'
example_images['new_filename_overlay'] = example_images['CELL'] + '_' + example_images['SIRNA'] + '_' + example_images['EU'] + '_' + example_images['well_name'] + '_nuclei.png'
example_images['filename_segmentation'] = 'nuclei_' + example_images['filename_ome_tiff']
example_images['intensity_rescaling_group'] = 'A'

# %%
example_images
# Out:
#                                 filename_ome_tiff    CELL        SIRNA  \
# 3    WellC06_Channel647,405_Seq0003_0004.ome.tiff  HCT116   ARMC5 pool
# 12   WellC08_Channel647,405_Seq0005_0004.ome.tiff  HCT116   ARMC5 pool
# 21   WellC04_Channel647,405_Seq0001_0004.ome.tiff  HCT116   ARMC5 pool
# 30   WellF06_Channel647,405_Seq0020_0004.ome.tiff  HCT116  No reaction
# 39   WellC07_Channel647,405_Seq0004_0004.ome.tiff  HCT116     Scramble
# 48   WellF04_Channel647,405_Seq0022_0004.ome.tiff  HCT116  No reaction
# 57   WellF05_Channel647,405_Seq0021_0004.ome.tiff  HCT116  No reaction
# 66   WellF03_Channel647,405_Seq0023_0004.ome.tiff  HCT116  No reaction
# 75   WellC03_Channel647,405_Seq0000_0004.ome.tiff  HCT116     Scramble
# 84   WellD06_Channel647,405_Seq0008_0004.ome.tiff  HCT116     Scramble
# 93   WellD08_Channel647,405_Seq0006_0004.ome.tiff  HCT116     Scramble
# 102  WellD05_Channel647,405_Seq0009_0004.ome.tiff  HCT116   ARMC5 pool
# 111  WellD07_Channel647,405_Seq0007_0004.ome.tiff  HCT116   ARMC5 pool
# 120  WellC05_Channel647,405_Seq0002_0004.ome.tiff  HCT116     Scramble
# 129  WellE04_Channel647,405_Seq0013_0004.ome.tiff  HCT116  No reaction
# 138  WellE08_Channel647,405_Seq0017_0004.ome.tiff  HCT116  No reaction
# 147  WellE06_Channel647,405_Seq0015_0004.ome.tiff  HCT116  No reaction
# 156  WellD03_Channel647,405_Seq0011_0004.ome.tiff  HCT116   ARMC5 pool
# 165  WellD04_Channel647,405_Seq0010_0004.ome.tiff  HCT116     Scramble
# 174  WellE05_Channel647,405_Seq0014_0004.ome.tiff  HCT116  No reaction
# 183  WellF08_Channel647,405_Seq0018_0004.ome.tiff  HCT116  No reaction
# 192  WellF07_Channel647,405_Seq0019_0004.ome.tiff  HCT116  No reaction
# 201  WellE07_Channel647,405_Seq0016_0004.ome.tiff  HCT116  No reaction
# 210  WellE03_Channel647,405_Seq0012_0004.ome.tiff  HCT116  No reaction
#
#          EU well_name                      new_filename  \
# 3    100 µM       C06  HCT116_ARMC5 pool_100 µM_C06.png
# 12   100 µM       C08  HCT116_ARMC5 pool_100 µM_C08.png
# 21   100 µM       C04  HCT116_ARMC5 pool_100 µM_C04.png
# 30    No EU       F06  HCT116_No reaction_No EU_F06.png
# 39   100 µM       C07    HCT116_Scramble_100 µM_C07.png
# 48    No EU       F04  HCT116_No reaction_No EU_F04.png
# 57    No EU       F05  HCT116_No reaction_No EU_F05.png
# 66    No EU       F03  HCT116_No reaction_No EU_F03.png
# 75   100 µM       C03    HCT116_Scramble_100 µM_C03.png
# 84   100 µM       D06    HCT116_Scramble_100 µM_D06.png
# 93   100 µM       D08    HCT116_Scramble_100 µM_D08.png
# 102  100 µM       D05  HCT116_ARMC5 pool_100 µM_D05.png
# 111  100 µM       D07  HCT116_ARMC5 pool_100 µM_D07.png
# 120  100 µM       C05    HCT116_Scramble_100 µM_C05.png
# 129   No EU       E04  HCT116_No reaction_No EU_E04.png
# 138   No EU       E08  HCT116_No reaction_No EU_E08.png
# 147   No EU       E06  HCT116_No reaction_No EU_E06.png
# 156  100 µM       D03  HCT116_ARMC5 pool_100 µM_D03.png
# 165  100 µM       D04    HCT116_Scramble_100 µM_D04.png
# 174   No EU       E05  HCT116_No reaction_No EU_E05.png
# 183   No EU       F08  HCT116_No reaction_No EU_F08.png
# 192   No EU       F07  HCT116_No reaction_No EU_F07.png
# 201   No EU       E07  HCT116_No reaction_No EU_E07.png
# 210   No EU       E03  HCT116_No reaction_No EU_E03.png
#
#                         new_filename_overlay  \
# 3    HCT116_ARMC5 pool_100 µM_C06_nuclei.png
# 12   HCT116_ARMC5 pool_100 µM_C08_nuclei.png
# 21   HCT116_ARMC5 pool_100 µM_C04_nuclei.png
# 30   HCT116_No reaction_No EU_F06_nuclei.png
# 39     HCT116_Scramble_100 µM_C07_nuclei.png
# 48   HCT116_No reaction_No EU_F04_nuclei.png
# 57   HCT116_No reaction_No EU_F05_nuclei.png
# 66   HCT116_No reaction_No EU_F03_nuclei.png
# 75     HCT116_Scramble_100 µM_C03_nuclei.png
# 84     HCT116_Scramble_100 µM_D06_nuclei.png
# 93     HCT116_Scramble_100 µM_D08_nuclei.png
# 102  HCT116_ARMC5 pool_100 µM_D05_nuclei.png
# 111  HCT116_ARMC5 pool_100 µM_D07_nuclei.png
# 120    HCT116_Scramble_100 µM_C05_nuclei.png
# 129  HCT116_No reaction_No EU_E04_nuclei.png
# 138  HCT116_No reaction_No EU_E08_nuclei.png
# 147  HCT116_No reaction_No EU_E06_nuclei.png
# 156  HCT116_ARMC5 pool_100 µM_D03_nuclei.png
# 165    HCT116_Scramble_100 µM_D04_nuclei.png
# 174  HCT116_No reaction_No EU_E05_nuclei.png
# 183  HCT116_No reaction_No EU_F08_nuclei.png
# 192  HCT116_No reaction_No EU_F07_nuclei.png
# 201  HCT116_No reaction_No EU_E07_nuclei.png
# 210  HCT116_No reaction_No EU_E03_nuclei.png
#
#                                  filename_segmentation  \
# 3    nuclei_WellC06_Channel647,405_Seq0003_0004.ome...
# 12   nuclei_WellC08_Channel647,405_Seq0005_0004.ome...
# 21   nuclei_WellC04_Channel647,405_Seq0001_0004.ome...
# 30   nuclei_WellF06_Channel647,405_Seq0020_0004.ome...
# 39   nuclei_WellC07_Channel647,405_Seq0004_0004.ome...
# 48   nuclei_WellF04_Channel647,405_Seq0022_0004.ome...
# 57   nuclei_WellF05_Channel647,405_Seq0021_0004.ome...
# 66   nuclei_WellF03_Channel647,405_Seq0023_0004.ome...
# 75   nuclei_WellC03_Channel647,405_Seq0000_0004.ome...
# 84   nuclei_WellD06_Channel647,405_Seq0008_0004.ome...
# 93   nuclei_WellD08_Channel647,405_Seq0006_0004.ome...
# 102  nuclei_WellD05_Channel647,405_Seq0009_0004.ome...
# 111  nuclei_WellD07_Channel647,405_Seq0007_0004.ome...
# 120  nuclei_WellC05_Channel647,405_Seq0002_0004.ome...
# 129  nuclei_WellE04_Channel647,405_Seq0013_0004.ome...
# 138  nuclei_WellE08_Channel647,405_Seq0017_0004.ome...
# 147  nuclei_WellE06_Channel647,405_Seq0015_0004.ome...
# 156  nuclei_WellD03_Channel647,405_Seq0011_0004.ome...
# 165  nuclei_WellD04_Channel647,405_Seq0010_0004.ome...
# 174  nuclei_WellE05_Channel647,405_Seq0014_0004.ome...
# 183  nuclei_WellF08_Channel647,405_Seq0018_0004.ome...
# 192  nuclei_WellF07_Channel647,405_Seq0019_0004.ome...
# 201  nuclei_WellE07_Channel647,405_Seq0016_0004.ome...
# 210  nuclei_WellE03_Channel647,405_Seq0012_0004.ome...
#
#     intensity_rescaling_group
# 3                           A
# 12                          A
# 21                          A
# 30                          A
# 39                          A
# 48                          A
# 57                          A
# 66                          A
# 75                          A
# 84                          A
# 93                          A
# 102                         A
# 111                         A
# 120                         A
# 129                         A
# 138                         A
# 147                         A
# 156                         A
# 165                         A
# 174                         A
# 183                         A
# 192                         A
# 201                         A
# 210                         A

# %%
from pathlib import Path
example_dir = Path(image_dir).parent / 'EXAMPLES' / 'RGB'
example_overlay_dir = Path(image_dir).parent / 'EXAMPLES' / 'RGB_OVERLAY'
if not example_dir.exists(): 
    example_dir.mkdir(parents=True)
if not example_overlay_dir.exists(): 
    example_overlay_dir.mkdir(parents=True)

# %%
# %%capture
example_images_grouped = example_images.query("SIRNA == 'ARMC5 pool' & EU!='No EU'").groupby('intensity_rescaling_group')
upper_rescale_values = {}
for group_name, group_data in example_images_grouped:
    group_of_image_files = group_data['filename_ome_tiff'].to_list()
    upper_rescale_value = []
    for image_filename in group_of_image_files:
        aics_image = AICSImage(Path(image_dir) / image_filename, reader=readers.ome_tiff_reader.OmeTiffReader )
        aics_image = illumination_correction.correct(aics_image)
        EU_array = aics_image.get_image_data('YX',Z=0,C=0,T=0)
        upper_rescale_value.append(np.quantile(EU_array,0.99))
    upper_rescale_values[group_name] = max(upper_rescale_value)

# %%
upper_rescale_values_df = pd.DataFrame(upper_rescale_values.items(), columns=['intensity_rescaling_group','upper_rescale_value'])
upper_rescale_values_df
example_images = example_images.merge(upper_rescale_values_df,on="intensity_rescaling_group")

# %%
example_images
# Out:
#                                filename_ome_tiff    CELL        SIRNA      EU  \
# 0   WellC06_Channel647,405_Seq0003_0004.ome.tiff  HCT116   ARMC5 pool  100 µM
# 1   WellC08_Channel647,405_Seq0005_0004.ome.tiff  HCT116   ARMC5 pool  100 µM
# 2   WellC04_Channel647,405_Seq0001_0004.ome.tiff  HCT116   ARMC5 pool  100 µM
# 3   WellF06_Channel647,405_Seq0020_0004.ome.tiff  HCT116  No reaction   No EU
# 4   WellC07_Channel647,405_Seq0004_0004.ome.tiff  HCT116     Scramble  100 µM
# 5   WellF04_Channel647,405_Seq0022_0004.ome.tiff  HCT116  No reaction   No EU
# 6   WellF05_Channel647,405_Seq0021_0004.ome.tiff  HCT116  No reaction   No EU
# 7   WellF03_Channel647,405_Seq0023_0004.ome.tiff  HCT116  No reaction   No EU
# 8   WellC03_Channel647,405_Seq0000_0004.ome.tiff  HCT116     Scramble  100 µM
# 9   WellD06_Channel647,405_Seq0008_0004.ome.tiff  HCT116     Scramble  100 µM
# 10  WellD08_Channel647,405_Seq0006_0004.ome.tiff  HCT116     Scramble  100 µM
# 11  WellD05_Channel647,405_Seq0009_0004.ome.tiff  HCT116   ARMC5 pool  100 µM
# 12  WellD07_Channel647,405_Seq0007_0004.ome.tiff  HCT116   ARMC5 pool  100 µM
# 13  WellC05_Channel647,405_Seq0002_0004.ome.tiff  HCT116     Scramble  100 µM
# 14  WellE04_Channel647,405_Seq0013_0004.ome.tiff  HCT116  No reaction   No EU
# 15  WellE08_Channel647,405_Seq0017_0004.ome.tiff  HCT116  No reaction   No EU
# 16  WellE06_Channel647,405_Seq0015_0004.ome.tiff  HCT116  No reaction   No EU
# 17  WellD03_Channel647,405_Seq0011_0004.ome.tiff  HCT116   ARMC5 pool  100 µM
# 18  WellD04_Channel647,405_Seq0010_0004.ome.tiff  HCT116     Scramble  100 µM
# 19  WellE05_Channel647,405_Seq0014_0004.ome.tiff  HCT116  No reaction   No EU
# 20  WellF08_Channel647,405_Seq0018_0004.ome.tiff  HCT116  No reaction   No EU
# 21  WellF07_Channel647,405_Seq0019_0004.ome.tiff  HCT116  No reaction   No EU
# 22  WellE07_Channel647,405_Seq0016_0004.ome.tiff  HCT116  No reaction   No EU
# 23  WellE03_Channel647,405_Seq0012_0004.ome.tiff  HCT116  No reaction   No EU
#
#    well_name                      new_filename  \
# 0        C06  HCT116_ARMC5 pool_100 µM_C06.png
# 1        C08  HCT116_ARMC5 pool_100 µM_C08.png
# 2        C04  HCT116_ARMC5 pool_100 µM_C04.png
# 3        F06  HCT116_No reaction_No EU_F06.png
# 4        C07    HCT116_Scramble_100 µM_C07.png
# 5        F04  HCT116_No reaction_No EU_F04.png
# 6        F05  HCT116_No reaction_No EU_F05.png
# 7        F03  HCT116_No reaction_No EU_F03.png
# 8        C03    HCT116_Scramble_100 µM_C03.png
# 9        D06    HCT116_Scramble_100 µM_D06.png
# 10       D08    HCT116_Scramble_100 µM_D08.png
# 11       D05  HCT116_ARMC5 pool_100 µM_D05.png
# 12       D07  HCT116_ARMC5 pool_100 µM_D07.png
# 13       C05    HCT116_Scramble_100 µM_C05.png
# 14       E04  HCT116_No reaction_No EU_E04.png
# 15       E08  HCT116_No reaction_No EU_E08.png
# 16       E06  HCT116_No reaction_No EU_E06.png
# 17       D03  HCT116_ARMC5 pool_100 µM_D03.png
# 18       D04    HCT116_Scramble_100 µM_D04.png
# 19       E05  HCT116_No reaction_No EU_E05.png
# 20       F08  HCT116_No reaction_No EU_F08.png
# 21       F07  HCT116_No reaction_No EU_F07.png
# 22       E07  HCT116_No reaction_No EU_E07.png
# 23       E03  HCT116_No reaction_No EU_E03.png
#
#                        new_filename_overlay  \
# 0   HCT116_ARMC5 pool_100 µM_C06_nuclei.png
# 1   HCT116_ARMC5 pool_100 µM_C08_nuclei.png
# 2   HCT116_ARMC5 pool_100 µM_C04_nuclei.png
# 3   HCT116_No reaction_No EU_F06_nuclei.png
# 4     HCT116_Scramble_100 µM_C07_nuclei.png
# 5   HCT116_No reaction_No EU_F04_nuclei.png
# 6   HCT116_No reaction_No EU_F05_nuclei.png
# 7   HCT116_No reaction_No EU_F03_nuclei.png
# 8     HCT116_Scramble_100 µM_C03_nuclei.png
# 9     HCT116_Scramble_100 µM_D06_nuclei.png
# 10    HCT116_Scramble_100 µM_D08_nuclei.png
# 11  HCT116_ARMC5 pool_100 µM_D05_nuclei.png
# 12  HCT116_ARMC5 pool_100 µM_D07_nuclei.png
# 13    HCT116_Scramble_100 µM_C05_nuclei.png
# 14  HCT116_No reaction_No EU_E04_nuclei.png
# 15  HCT116_No reaction_No EU_E08_nuclei.png
# 16  HCT116_No reaction_No EU_E06_nuclei.png
# 17  HCT116_ARMC5 pool_100 µM_D03_nuclei.png
# 18    HCT116_Scramble_100 µM_D04_nuclei.png
# 19  HCT116_No reaction_No EU_E05_nuclei.png
# 20  HCT116_No reaction_No EU_F08_nuclei.png
# 21  HCT116_No reaction_No EU_F07_nuclei.png
# 22  HCT116_No reaction_No EU_E07_nuclei.png
# 23  HCT116_No reaction_No EU_E03_nuclei.png
#
#                                 filename_segmentation  \
# 0   nuclei_WellC06_Channel647,405_Seq0003_0004.ome...
# 1   nuclei_WellC08_Channel647,405_Seq0005_0004.ome...
# 2   nuclei_WellC04_Channel647,405_Seq0001_0004.ome...
# 3   nuclei_WellF06_Channel647,405_Seq0020_0004.ome...
# 4   nuclei_WellC07_Channel647,405_Seq0004_0004.ome...
# 5   nuclei_WellF04_Channel647,405_Seq0022_0004.ome...
# 6   nuclei_WellF05_Channel647,405_Seq0021_0004.ome...
# 7   nuclei_WellF03_Channel647,405_Seq0023_0004.ome...
# 8   nuclei_WellC03_Channel647,405_Seq0000_0004.ome...
# 9   nuclei_WellD06_Channel647,405_Seq0008_0004.ome...
# 10  nuclei_WellD08_Channel647,405_Seq0006_0004.ome...
# 11  nuclei_WellD05_Channel647,405_Seq0009_0004.ome...
# 12  nuclei_WellD07_Channel647,405_Seq0007_0004.ome...
# 13  nuclei_WellC05_Channel647,405_Seq0002_0004.ome...
# 14  nuclei_WellE04_Channel647,405_Seq0013_0004.ome...
# 15  nuclei_WellE08_Channel647,405_Seq0017_0004.ome...
# 16  nuclei_WellE06_Channel647,405_Seq0015_0004.ome...
# 17  nuclei_WellD03_Channel647,405_Seq0011_0004.ome...
# 18  nuclei_WellD04_Channel647,405_Seq0010_0004.ome...
# 19  nuclei_WellE05_Channel647,405_Seq0014_0004.ome...
# 20  nuclei_WellF08_Channel647,405_Seq0018_0004.ome...
# 21  nuclei_WellF07_Channel647,405_Seq0019_0004.ome...
# 22  nuclei_WellE07_Channel647,405_Seq0016_0004.ome...
# 23  nuclei_WellE03_Channel647,405_Seq0012_0004.ome...
#
#    intensity_rescaling_group  upper_rescale_value
# 0                          A                711.0
# 1                          A                711.0
# 2                          A                711.0
# 3                          A                711.0
# 4                          A                711.0
# 5                          A                711.0
# 6                          A                711.0
# 7                          A                711.0
# 8                          A                711.0
# 9                          A                711.0
# 10                         A                711.0
# 11                         A                711.0
# 12                         A                711.0
# 13                         A                711.0
# 14                         A                711.0
# 15                         A                711.0
# 16                         A                711.0
# 17                         A                711.0
# 18                         A                711.0
# 19                         A                711.0
# 20                         A                711.0
# 21                         A                711.0
# 22                         A                711.0
# 23                         A                711.0

# %%
# %%capture
for index, row in example_images.iterrows():
    aics_image = AICSImage(Path(image_dir) / row["filename_ome_tiff"], reader=readers.ome_tiff_reader.OmeTiffReader)
    aics_image = illumination_correction.correct(aics_image)
    EU_array = aics_image.get_image_data('YX',Z=0,C=0,T=0)
    lower_rescale_value = 120
    EU_array_rescaled = (EU_array.astype(float) - lower_rescale_value) / row["upper_rescale_value"]
    pil_image = Image.fromarray(cm.magma(EU_array_rescaled.clip(0,1),bytes=True)).convert('RGB')
    pil_image.save(str(example_dir / row["new_filename"]), quality=85, subsampling=0)
    
    # add segmentation overlay
    segmentation_aics_image = AICSImage(Path(label_image_dir) / row["filename_segmentation"], reader=readers.ome_tiff_reader.OmeTiffReader)
    segmentation_array = segmentation_aics_image.get_image_data('YX',Z=0,C=0,T=0)
    segmentation_pil_image = Image.fromarray(segmentation_array)
    overlay_image = create_overlay_image_plot(pil_image,segmentation_pil_image,thin=True)
    overlay_image.save(str(example_overlay_dir / row["new_filename_overlay"]), quality=85, subsampling=0)

# %%
import matplotlib.pyplot as plt
import numpy as np

cmaps = [('Perceptually Uniform Sequential', [
            'viridis', 'plasma', 'inferno', 'magma', 'cividis']),
         ('Sequential', [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']),
         ('Sequential (2)', [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']),
         ('Diverging', [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']),
         ('Cyclic', ['twilight', 'twilight_shifted', 'hsv']),
         ('Qualitative', [
            'Pastel1', 'Pastel2', 'Paired', 'Accent',
            'Dark2', 'Set1', 'Set2', 'Set3',
            'tab10', 'tab20', 'tab20b', 'tab20c']),
         ('Miscellaneous', [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
            'gist_rainbow', 'rainbow', 'jet', 'turbo', 'nipy_spectral',
            'gist_ncar'])]

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

def plot_color_gradients(cmap_category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows-1)*0.1)*0.22
    fig, axs = plt.subplots(nrows=nrows, figsize=(6.4, figh))
    fig.subplots_adjust(top=1-.35/figh, bottom=.15/figh, left=0.2, right=0.99)

    axs[0].set_title(f"{cmap_category} colormaps", fontsize=14)

    for ax, cmap_name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=cmap_name)
        ax.text(-.01, .5, cmap_name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()
        
    return fig


colormaps = plot_color_gradients('Perceptually Uniform Sequential', ['inferno','viridis','magma'])

colormaps.savefig(str(Path(image_dir).parent / 'EXAMPLES' / 'colormap.png'))

# %%
example_dir
# Out:
# PosixPath('/srv/scratch/berrylab/z3532965/NikonSpinningDisk/ARMC5_KD_EU/240628_ARMC5_EU/Cycle2_EU/20240701_175159_151/EXAMPLES/RGB')

# %%
aics_image.channel_names
# Out:
# ['647', '405']

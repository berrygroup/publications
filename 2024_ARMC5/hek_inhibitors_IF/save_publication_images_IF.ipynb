# %%
import os
import glob
import napari
import pandas as pd
import numpy as np
import mahotas as mh

from pathlib import Path
from aicsimageio import AICSImage, readers
from blimp.preprocessing.illumination_correction import IlluminationCorrection

from PIL import Image
from matplotlib import cm

data_dir = "/srv/scratch/berrylab/z3532965/NikonSpinningDisk/240314/240311_ARMC5KO_IF/"
image_dir = os.path.join(data_dir,"20240314_185145_903/OME-TIFF-MIP")
label_image_dir = os.path.join(data_dir,"20240314_185145_903/SEGMENTATION")

ana_dir = "/srv/scratch/z3532965/src/publications/2024_ARMC5/hek_inhibitors_IF"
illum_corr_file = os.path.join(data_dir,"/srv/scratch/berrylab/z3532965/NikonSpinningDisk/240305/ILLUMCORR/illumination_correction.pkl")
# Out:
# 27-Jun-24 10:33:03 - bfio.backends - WARNING  - Java backend is not available. This could be due to a missing dependency (jpype).

# %%
def create_overlay_image_plot(
        channel_image, label_image,
        color='rgb(255, 191, 0)', thin=False):

    # threshold label_image and generate outlines
    label_image = np.array(label_image)
    if (thin):
        outlines = mh.labeled.borders(label_image) * 255
    else:
        outlines = mh.morph.dilate(mh.labeled.borders(label_image)) * 255
    overlay = Image.fromarray(np.uint8(outlines))
    outlines_transparent = Image.new(
        mode='RGBA', size=outlines.shape[::-1], color=(0, 0, 0, 0)
    )

    channel_image = channel_image.convert("RGBA")
    outlines_transparent.paste(channel_image, (0,0))
    outlines_transparent.paste(overlay, (0,0), mask=overlay)

    return outlines_transparent

# %% [markdown]
# ## Load metadata
# We have a csv file of the plate layout that includes information on antibody staining

# %%
import re

plate_layout = pd.read_csv(os.path.join(ana_dir,"METADATA","240311_ARMC5KO_IF_longlayout.csv"))
plate_layout.columns

def pad_well_names(name):
    return re.sub(r'(\D)(\d)$', r'\g<1>0\2', name)

# Apply the function to the DataFrame column in place
plate_layout['Well name'] = plate_layout['Well name'].apply(lambda x: pad_well_names(x))

# %% [markdown]
# ## Apply illumination correction
#
# Load illumination correction object

# %%
illumination_correction = IlluminationCorrection(from_file=illum_corr_file)

# %% [markdown]
# ## Join image metadata and plate layout

# %%
image_metadata_files = glob.glob(os.path.join(image_dir,"*.csv"))
image_metadata = pd.concat((pd.read_csv(f) for f in image_metadata_files), ignore_index=True)
image_metadata['well_name'] = image_metadata['filename_ome_tiff'].str.extract(r'Well([A-Z]\d{2})_Channel')
image_metadata.columns
# Out:
# Index(['n_pixels_y', 'n_pixels_x', 'objective_name', 'pixel_size_microns',
#        'field_id', 'timepoint_id', 'filename_ome_tiff', 'acquisition_time_rel',
#        'stage_y_abs', 'stage_x_abs', 'stage_z_n', 'acquisition_time_abs',
#        'standard_field_id', 'metadata_string_acquisition_0',
#        'metadata_string_acquisition_1', 'metadata_string_acquisition_2',
#        'metadata_string_acquisition_3', 'well_name'],
#       dtype='object')

# %%
image_metadata_annotated = image_metadata.merge(plate_layout,left_on="well_name", right_on="Well name")

# %%
image_metadata_annotated.query(
    "Cell == 'HEK293 parental' and Primary == 'None' and field_id == 1")
# Out:
#       n_pixels_y  n_pixels_x  objective_name  pixel_size_microns  field_id  \
# 896         2304        2304  Plan Apo λ 40x              0.1625         1
# 1264        2304        2304  Plan Apo λ 40x              0.1625         1
#
#       timepoint_id                                  filename_ome_tiff  \
# 896              0  WellI12_ChannelNone,488,647,405_Seq0063_0001.o...
# 1264             0  WellL12_ChannelNone,488,647,405_Seq0084_0001.o...
#
#       acquisition_time_rel   stage_y_abs  stage_x_abs  ...  \
# 896           11044.246348   1636.209524  2930.995238  ...
# 1264          14714.854062  15136.242857  2949.200000  ...
#
#                           metadata_string_acquisition_1  \
# 896   Plane #2:\n Name: 488\n Component Count: 1\n M...
# 1264  Plane #2:\n Name: 488\n Component Count: 1\n M...
#
#                           metadata_string_acquisition_2  \
# 896   Plane #3:\n Name: 647\n Component Count: 1\n M...
# 1264  Plane #3:\n Name: 647\n Component Count: 1\n M...
#
#                           metadata_string_acquisition_3 well_name Well name  \
# 896   Plane #4:\n Name: 405\n Component Count: 1\n M...       I12       I12
# 1264  Plane #4:\n Name: 405\n Component Count: 1\n M...       L12       L12
#
#                  Cell  Drug Drug time Primary                 Secondary
# 896   HEK293 parental  None      None    None  Goat anti-mouse Alexa488
# 1264  HEK293 parental  None      None    None    Goat anti-rat Alexa488
#
# [2 rows x 24 columns]

# %% [markdown]
# ## Save Examples

# %%
example_images = image_metadata_annotated.query("field_id == 4")[['filename_ome_tiff','Primary','Secondary','Cell','Drug','well_name']]
example_images['new_filename'] = example_images['Cell'] + '_' + example_images['Drug'] + '_' + example_images['Primary'] + '_' + example_images['Secondary'] + '_' + example_images['well_name'] + '.png'
example_images['new_filename_overlay'] = example_images['Cell'] + '_' + example_images['Drug'] + '_' + example_images['Primary'] + '_' + example_images['Secondary'] + '_' + example_images['well_name'] + '_nuclei.png'
example_images['filename_segmentation'] = 'nuclei_' + example_images['filename_ome_tiff']
example_images['intensity_rescaling_group'] = example_images['Primary']

# %%
example_images
# Out:
#                                       filename_ome_tiff            Primary  \
# 3     WellJ08_ChannelNone,488,647,405_Seq0068_0004.o...  pSer2 Pol II 3E10
# 19    WellJ07_ChannelNone,488,647,405_Seq0069_0004.o...   pSer5 Pol II 3E8
# 35    WellJ09_ChannelNone,488,647,405_Seq0067_0004.o...   Total Pol II F12
# 51    WellM10_ChannelNone,488,647,405_Seq0101_0004.o...   pSer5 Pol II 3E8
# 67    WellC08_ChannelNone,488,647,405_Seq0005_0004.o...  pSer2 Pol II 3E10
# ...                                                 ...                ...
# 1747  WellN09_ChannelNone,488,647,405_Seq0107_0004.o...   Total Pol II F12
# 1763  WellN07_ChannelNone,488,647,405_Seq0109_0004.o...   pSer5 Pol II 3E8
# 1779  WellI08_ChannelNone,488,647,405_Seq0059_0004.o...  pSer2 Pol II 3E10
# 1795  WellM04_ChannelNone,488,647,405_Seq0095_0004.o...   pSer5 Pol II 3E8
# 1811  WellK06_ChannelNone,488,647,405_Seq0077_0004.o...   Total Pol II F12
#
#                      Secondary                 Cell               Drug  \
# 3       Goat anti-rat Alexa488  HEK293 ARMC5 KO 1A3       AZD4573 1 µM
# 19      Goat anti-rat Alexa488  HEK293 ARMC5 KO 1A3       AZD4573 1 µM
# 35    Goat anti-mouse Alexa488  HEK293 ARMC5 KO 1A3            Vehicle
# 51      Goat anti-rat Alexa488  HEK293 ARMC5 KO 1A3            Vehicle
# 67      Goat anti-rat Alexa488      HEK293 parental      LDC4297 10 µM
# ...                        ...                  ...                ...
# 1747  Goat anti-mouse Alexa488  HEK293 ARMC5 KO 2B6            Vehicle
# 1763    Goat anti-rat Alexa488  HEK293 ARMC5 KO 2B6       AZD4573 1 µM
# 1779    Goat anti-rat Alexa488      HEK293 parental       AZD4573 1 µM
# 1795    Goat anti-rat Alexa488  HEK293 ARMC5 KO 1A3  Triptolide 300 nM
# 1811  Goat anti-mouse Alexa488  HEK293 ARMC5 KO 2B6       AZD4573 1 µM
#
#      well_name                                       new_filename  \
# 3          J08  HEK293 ARMC5 KO 1A3_AZD4573 1 µM_pSer2 Pol II ...
# 19         J07  HEK293 ARMC5 KO 1A3_AZD4573 1 µM_pSer5 Pol II ...
# 35         J09  HEK293 ARMC5 KO 1A3_Vehicle_Total Pol II F12_G...
# 51         M10  HEK293 ARMC5 KO 1A3_Vehicle_pSer5 Pol II 3E8_G...
# 67         C08  HEK293 parental_LDC4297 10 µM_pSer2 Pol II 3E1...
# ...        ...                                                ...
# 1747       N09  HEK293 ARMC5 KO 2B6_Vehicle_Total Pol II F12_G...
# 1763       N07  HEK293 ARMC5 KO 2B6_AZD4573 1 µM_pSer5 Pol II ...
# 1779       I08  HEK293 parental_AZD4573 1 µM_pSer2 Pol II 3E10...
# 1795       M04  HEK293 ARMC5 KO 1A3_Triptolide 300 nM_pSer5 Po...
# 1811       K06  HEK293 ARMC5 KO 2B6_AZD4573 1 µM_Total Pol II ...
#
#                                    new_filename_overlay  \
# 3     HEK293 ARMC5 KO 1A3_AZD4573 1 µM_pSer2 Pol II ...
# 19    HEK293 ARMC5 KO 1A3_AZD4573 1 µM_pSer5 Pol II ...
# 35    HEK293 ARMC5 KO 1A3_Vehicle_Total Pol II F12_G...
# 51    HEK293 ARMC5 KO 1A3_Vehicle_pSer5 Pol II 3E8_G...
# 67    HEK293 parental_LDC4297 10 µM_pSer2 Pol II 3E1...
# ...                                                 ...
# 1747  HEK293 ARMC5 KO 2B6_Vehicle_Total Pol II F12_G...
# 1763  HEK293 ARMC5 KO 2B6_AZD4573 1 µM_pSer5 Pol II ...
# 1779  HEK293 parental_AZD4573 1 µM_pSer2 Pol II 3E10...
# 1795  HEK293 ARMC5 KO 1A3_Triptolide 300 nM_pSer5 Po...
# 1811  HEK293 ARMC5 KO 2B6_AZD4573 1 µM_Total Pol II ...
#
#                                   filename_segmentation  \
# 3     nuclei_WellJ08_ChannelNone,488,647,405_Seq0068...
# 19    nuclei_WellJ07_ChannelNone,488,647,405_Seq0069...
# 35    nuclei_WellJ09_ChannelNone,488,647,405_Seq0067...
# 51    nuclei_WellM10_ChannelNone,488,647,405_Seq0101...
# 67    nuclei_WellC08_ChannelNone,488,647,405_Seq0005...
# ...                                                 ...
# 1747  nuclei_WellN09_ChannelNone,488,647,405_Seq0107...
# 1763  nuclei_WellN07_ChannelNone,488,647,405_Seq0109...
# 1779  nuclei_WellI08_ChannelNone,488,647,405_Seq0059...
# 1795  nuclei_WellM04_ChannelNone,488,647,405_Seq0095...
# 1811  nuclei_WellK06_ChannelNone,488,647,405_Seq0077...
#
#      intensity_rescaling_group
# 3            pSer2 Pol II 3E10
# 19            pSer5 Pol II 3E8
# 35            Total Pol II F12
# 51            pSer5 Pol II 3E8
# 67           pSer2 Pol II 3E10
# ...                        ...
# 1747          Total Pol II F12
# 1763          pSer5 Pol II 3E8
# 1779         pSer2 Pol II 3E10
# 1795          pSer5 Pol II 3E8
# 1811          Total Pol II F12
#
# [114 rows x 10 columns]

# %%
from pathlib import Path
example_dir = Path(image_dir).parent / 'EXAMPLES' / 'RGB'
example_overlay_dir = Path(image_dir).parent / 'EXAMPLES' / 'RGB_OVERLAY'
if not example_dir.exists(): 
    example_dir.mkdir(parents=True)
if not example_overlay_dir.exists(): 
    example_overlay_dir.mkdir(parents=True)

# %%
# %%capture
example_images_grouped = example_images.query("Drug == 'Vehicle'").groupby('intensity_rescaling_group')
upper_rescale_values = {}
for group_name, group_data in example_images_grouped:
    group_of_image_files = group_data['filename_ome_tiff'].to_list()
    upper_rescale_value = []
    for image_filename in group_of_image_files:
        aics_image = AICSImage(Path(image_dir) / image_filename, reader=readers.ome_tiff_reader.OmeTiffReader )
        aics_image = illumination_correction.correct(aics_image)
        IF_array = aics_image.get_image_data('YX',Z=0,C=1,T=0)[500:,:] # crop
        upper_rescale_value.append(np.quantile(IF_array,0.99))
    upper_rescale_values[group_name] = max(upper_rescale_value)

# %%
upper_rescale_values_df = pd.DataFrame(upper_rescale_values.items(), columns=['intensity_rescaling_group','upper_rescale_value'])
upper_rescale_values_df
example_images_primary = example_images.merge(upper_rescale_values_df,on="intensity_rescaling_group")

# %%
# %%capture
for index, row in example_images_primary.iterrows():
    aics_image = AICSImage(Path(image_dir) / row["filename_ome_tiff"], reader=readers.ome_tiff_reader.OmeTiffReader)
    aics_image = illumination_correction.correct(aics_image)
    IF_array = aics_image.get_image_data('YX',Z=0,C=1,T=0)[:,500:] # crop
    lower_rescale_value = 147
    IF_array_rescaled = (IF_array.astype(float) - lower_rescale_value) / row["upper_rescale_value"]
    pil_image = Image.fromarray(cm.magma(IF_array_rescaled.clip(0,1),bytes=True)).convert('RGB')
    pil_image.save(str(example_dir / row["new_filename"]), quality=85, subsampling=0)
    
    # add segmentation overlay
    segmentation_aics_image = AICSImage(Path(label_image_dir) / row["filename_segmentation"], reader=readers.ome_tiff_reader.OmeTiffReader)
    segmentation_array = segmentation_aics_image.get_image_data('YX',Z=0,C=0,T=0) # already cropped
    segmentation_pil_image = Image.fromarray(segmentation_array)
    overlay_image = create_overlay_image_plot(pil_image,segmentation_pil_image,thin=True)
    overlay_image.save(str(example_overlay_dir / row["new_filename_overlay"]), quality=85, subsampling=0)

# %%
corresponding_secondaries = upper_rescale_values_df.merge(
    image_metadata_annotated.drop_duplicates(['Primary','Secondary'])[['Primary','Secondary']],
    left_on='intensity_rescaling_group',right_on='Primary').drop('Primary',axis=1)
corresponding_secondaries
# Out:
#   intensity_rescaling_group  upper_rescale_value                 Secondary
# 0          Total Pol II F12                704.0  Goat anti-mouse Alexa488
# 1         pSer2 Pol II 3E10                803.0    Goat anti-rat Alexa488
# 2          pSer5 Pol II 3E8               2305.0    Goat anti-rat Alexa488

# %%
secondary_only = example_images.query("Primary == 'None'").drop('intensity_rescaling_group',axis=1).merge(
    corresponding_secondaries,
    left_on='Secondary',
    right_on='Secondary')
secondary_only['new_filename'] = secondary_only['Cell'] + '_' + secondary_only['Drug'] + '_' + secondary_only['Primary'] + '_' + secondary_only['Secondary'] + '_' + secondary_only['well_name'] + '_rescaled_for_' + secondary_only['intensity_rescaling_group'] + '.png'
secondary_only['new_filename_overlay'] = secondary_only['Cell'] + '_' + secondary_only['Drug'] + '_' + secondary_only['Primary'] + '_' + secondary_only['Secondary'] + '_' + secondary_only['well_name'] + '_rescaled_for_' + secondary_only['intensity_rescaling_group'] + '_nuclei.png'
secondary_only
# Out:
#                                    filename_ome_tiff Primary  \
# 0  WellM12_ChannelNone,488,647,405_Seq0103_0004.o...    None
# 1  WellM12_ChannelNone,488,647,405_Seq0103_0004.o...    None
# 2  WellN12_ChannelNone,488,647,405_Seq0104_0004.o...    None
# 3  WellN12_ChannelNone,488,647,405_Seq0104_0004.o...    None
# 4  WellL12_ChannelNone,488,647,405_Seq0084_0004.o...    None
# 5  WellL12_ChannelNone,488,647,405_Seq0084_0004.o...    None
# 6  WellK12_ChannelNone,488,647,405_Seq0083_0004.o...    None
# 7  WellI12_ChannelNone,488,647,405_Seq0063_0004.o...    None
# 8  WellJ12_ChannelNone,488,647,405_Seq0064_0004.o...    None
#
#                   Secondary                 Cell  Drug well_name  \
# 0    Goat anti-rat Alexa488  HEK293 ARMC5 KO 1A3  None       M12
# 1    Goat anti-rat Alexa488  HEK293 ARMC5 KO 1A3  None       M12
# 2    Goat anti-rat Alexa488  HEK293 ARMC5 KO 2B6  None       N12
# 3    Goat anti-rat Alexa488  HEK293 ARMC5 KO 2B6  None       N12
# 4    Goat anti-rat Alexa488      HEK293 parental  None       L12
# 5    Goat anti-rat Alexa488      HEK293 parental  None       L12
# 6  Goat anti-mouse Alexa488  HEK293 ARMC5 KO 2B6  None       K12
# 7  Goat anti-mouse Alexa488      HEK293 parental  None       I12
# 8  Goat anti-mouse Alexa488  HEK293 ARMC5 KO 1A3  None       J12
#
#                                         new_filename  \
# 0  HEK293 ARMC5 KO 1A3_None_None_Goat anti-rat Al...
# 1  HEK293 ARMC5 KO 1A3_None_None_Goat anti-rat Al...
# 2  HEK293 ARMC5 KO 2B6_None_None_Goat anti-rat Al...
# 3  HEK293 ARMC5 KO 2B6_None_None_Goat anti-rat Al...
# 4  HEK293 parental_None_None_Goat anti-rat Alexa4...
# 5  HEK293 parental_None_None_Goat anti-rat Alexa4...
# 6  HEK293 ARMC5 KO 2B6_None_None_Goat anti-mouse ...
# 7  HEK293 parental_None_None_Goat anti-mouse Alex...
# 8  HEK293 ARMC5 KO 1A3_None_None_Goat anti-mouse ...
#
#                                 new_filename_overlay  \
# 0  HEK293 ARMC5 KO 1A3_None_None_Goat anti-rat Al...
# 1  HEK293 ARMC5 KO 1A3_None_None_Goat anti-rat Al...
# 2  HEK293 ARMC5 KO 2B6_None_None_Goat anti-rat Al...
# 3  HEK293 ARMC5 KO 2B6_None_None_Goat anti-rat Al...
# 4  HEK293 parental_None_None_Goat anti-rat Alexa4...
# 5  HEK293 parental_None_None_Goat anti-rat Alexa4...
# 6  HEK293 ARMC5 KO 2B6_None_None_Goat anti-mouse ...
# 7  HEK293 parental_None_None_Goat anti-mouse Alex...
# 8  HEK293 ARMC5 KO 1A3_None_None_Goat anti-mouse ...
#
#                                filename_segmentation  \
# 0  nuclei_WellM12_ChannelNone,488,647,405_Seq0103...
# 1  nuclei_WellM12_ChannelNone,488,647,405_Seq0103...
# 2  nuclei_WellN12_ChannelNone,488,647,405_Seq0104...
# 3  nuclei_WellN12_ChannelNone,488,647,405_Seq0104...
# 4  nuclei_WellL12_ChannelNone,488,647,405_Seq0084...
# 5  nuclei_WellL12_ChannelNone,488,647,405_Seq0084...
# 6  nuclei_WellK12_ChannelNone,488,647,405_Seq0083...
# 7  nuclei_WellI12_ChannelNone,488,647,405_Seq0063...
# 8  nuclei_WellJ12_ChannelNone,488,647,405_Seq0064...
#
#   intensity_rescaling_group  upper_rescale_value
# 0         pSer2 Pol II 3E10                803.0
# 1          pSer5 Pol II 3E8               2305.0
# 2         pSer2 Pol II 3E10                803.0
# 3          pSer5 Pol II 3E8               2305.0
# 4         pSer2 Pol II 3E10                803.0
# 5          pSer5 Pol II 3E8               2305.0
# 6          Total Pol II F12                704.0
# 7          Total Pol II F12                704.0
# 8          Total Pol II F12                704.0

# %%
# %%capture
for index, row in secondary_only.iterrows():
    aics_image = AICSImage(Path(image_dir) / row["filename_ome_tiff"], reader=readers.ome_tiff_reader.OmeTiffReader)
    aics_image = illumination_correction.correct(aics_image)
    IF_array = aics_image.get_image_data('YX',Z=0,C=1,T=0)[:,500:] # crop
    lower_rescale_value = 147
    IF_array_rescaled = (IF_array.astype(float) - lower_rescale_value) / row["upper_rescale_value"]
    pil_image = Image.fromarray(cm.magma(IF_array_rescaled.clip(0,1),bytes=True)).convert('RGB')
    pil_image.save(str(example_dir / row["new_filename"]), quality=85, subsampling=0)
    
    # add segmentation overlay
    segmentation_aics_image = AICSImage(Path(label_image_dir) / row["filename_segmentation"], reader=readers.ome_tiff_reader.OmeTiffReader)
    segmentation_array = segmentation_aics_image.get_image_data('YX',Z=0,C=0,T=0) # already cropped
    segmentation_pil_image = Image.fromarray(segmentation_array)
    overlay_image = create_overlay_image_plot(pil_image,segmentation_pil_image,thin=True)
    overlay_image.save(str(example_overlay_dir / row["new_filename_overlay"]), quality=85, subsampling=0)

# %%
import matplotlib.pyplot as plt
import numpy as np

cmaps = [('Perceptually Uniform Sequential', [
            'viridis', 'plasma', 'inferno', 'magma', 'cividis']),
         ('Sequential', [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']),
         ('Sequential (2)', [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']),
         ('Diverging', [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']),
         ('Cyclic', ['twilight', 'twilight_shifted', 'hsv']),
         ('Qualitative', [
            'Pastel1', 'Pastel2', 'Paired', 'Accent',
            'Dark2', 'Set1', 'Set2', 'Set3',
            'tab10', 'tab20', 'tab20b', 'tab20c']),
         ('Miscellaneous', [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
            'gist_rainbow', 'rainbow', 'jet', 'turbo', 'nipy_spectral',
            'gist_ncar'])]

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

def plot_color_gradients(cmap_category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows-1)*0.1)*0.22
    fig, axs = plt.subplots(nrows=nrows, figsize=(6.4, figh))
    fig.subplots_adjust(top=1-.35/figh, bottom=.15/figh, left=0.2, right=0.99)

    axs[0].set_title(f"{cmap_category} colormaps", fontsize=14)

    for ax, cmap_name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=cmap_name)
        ax.text(-.01, .5, cmap_name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()
        
    return fig


colormaps = plot_color_gradients('Perceptually Uniform Sequential', ['inferno','viridis','magma'])

colormaps.savefig(str(Path(image_dir).parent / 'EXAMPLES' / 'colormap.png'))

# %%
example_dir
# Out:
# PosixPath('/srv/scratch/berrylab/z3532965/NikonSpinningDisk/240314/240311_ARMC5KO_IF/20240314_185145_903/EXAMPLES/RGB')

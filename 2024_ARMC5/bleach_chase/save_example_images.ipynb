# %%
import os
import glob
import napari
import pandas as pd
import numpy as np
#import pyclesperanto_prototype as cle

from pathlib import Path
from aicsimageio import AICSImage, readers
from blimp.processing.segment_and_quantify import segment_nuclei_cellpose, quantify
from blimp.preprocessing.illumination_correction import IlluminationCorrection

data_dir = "/srv/scratch/berrylab/z3532965/systems_Ti2/202402_BleachChase_mCherry-POLR2A/"
image_dir = os.path.join(data_dir,"20240208_085709_941/OME-TIFF-MIP")
image_dir_3D = os.path.join(data_dir,"20240208_085709_941/OME-TIFF")

ana_dir = "/srv/scratch/z3532965/src/blana/Scott/202402_BleachChase_mCherry-POLR2A"
illum_corr_file = os.path.join(data_dir,"ILLUMCORR/illumination_correction.pkl")
# Out:
# 03-Mar-24 15:27:31 - bfio.backends - WARNING  - Java backend is not available. This could be due to a missing dependency (jpype).

# %% [markdown]
# # Load metadata
# We have a csv file of the plate layout that includes information on antibody staining

# %%
plate_layout = pd.read_csv(os.path.join(ana_dir,"METADATA","plate_layout.csv"))
plate_layout.columns
# Out:
# Index(['well_name', 'siRNA', 'replicate'], dtype='object')

# %% [markdown]
# # Apply illumination correction
#
# Load illumination correction object

# %%
illumination_correction = IlluminationCorrection(from_file=illum_corr_file)

# %%
image_metadata_files = glob.glob(os.path.join(image_dir,"*.csv"))
image_metadata = pd.concat((pd.read_csv(f) for f in image_metadata_files), ignore_index=True)
image_metadata['well_name'] = image_metadata['filename_ome_tiff'].str.extract(r'Well([A-Z]\d{2})_Channel')
image_metadata['channel'] = image_metadata['filename_ome_tiff'].str.extract(r'Channel(TRITC|Red)')
image_metadata.columns
# Out:
# Index(['n_pixels_y', 'n_pixels_x', 'objective_name', 'pixel_size_microns',
#        'field_id', 'timepoint_id', 'filename_ome_tiff', 'acquisition_time_rel',
#        'stage_y_abs', 'stage_x_abs', 'stage_z_n', 'acquisition_time_abs',
#        'standard_field_id', 'metadata_string_acquisition_0', 'well_name',
#        'channel'],
#       dtype='object')

# %%
image_metadata_annotated = image_metadata.merge(plate_layout,left_on="well_name", right_on="well_name")

# %%
image_metadata_annotated.query("siRNA=='ARMC5' & replicate == 1 & field_id == 1")
# Out:
#      n_pixels_y  n_pixels_x          objective_name  pixel_size_microns  \
# 0          2304        2304  Plan Apo VC 20x DIC N2               0.325
# 9          2304        2304  Plan Apo VC 20x DIC N2               0.325
# 18         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 27         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 36         2304        2304  Plan Apo VC 20x DIC N2               0.325
# ..          ...         ...                     ...                 ...
# 783        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 792        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 801        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 810        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 819        2304        2304  Plan Apo VC 20x DIC N2               0.325
#
#      field_id  timepoint_id                               filename_ome_tiff  \
# 0           1             0  WellD06_ChannelRed_Scott_Seq0005_0001.ome.tiff
# 9           1             1  WellD06_ChannelRed_Scott_Seq0005_0001.ome.tiff
# 18          1             2  WellD06_ChannelRed_Scott_Seq0005_0001.ome.tiff
# 27          1             3  WellD06_ChannelRed_Scott_Seq0005_0001.ome.tiff
# 36          1             0      WellD06_ChannelTRITC_Seq0003_0001.ome.tiff
# ..        ...           ...                                             ...
# 783         1             1      WellD06_ChannelTRITC_Seq0001_0001.ome.tiff
# 792         1             2      WellD06_ChannelTRITC_Seq0001_0001.ome.tiff
# 801         1             3      WellD06_ChannelTRITC_Seq0001_0001.ome.tiff
# 810         1             4      WellD06_ChannelTRITC_Seq0001_0001.ome.tiff
# 819         1             5      WellD06_ChannelTRITC_Seq0001_0001.ome.tiff
#
#      acquisition_time_rel  stage_y_abs  stage_x_abs  stage_z_n  \
# 0             4912.295424 -5616.985714  3204.700000          7
# 9             5571.710209 -5617.171429  3204.600000          7
# 18            6231.221320 -5617.285714  3204.614286          7
# 27            6890.685189 -5617.100000  3204.600000          7
# 36             200.687898 -5617.142857  6004.500000          7
# ..                    ...          ...          ...        ...
# 783            930.540839 -5616.985714  3204.614286          7
# 792           1791.316360 -5617.128571  3204.800000          7
# 801           2651.317142 -5617.057143  3204.514286          7
# 810           3511.711520 -5617.185714  3204.800000          7
# 819           4371.421372 -5617.100000  3204.800000          7
#
#            acquisition_time_abs  standard_field_id  \
# 0    2024-08-02 12:18:59.295424                  3
# 9    2024-08-02 12:29:58.710209                  3
# 18   2024-08-02 12:40:58.221320                  3
# 27   2024-08-02 12:51:57.685189                  3
# 36   2024-08-02 10:16:31.687898                  3
# ..                          ...                ...
# 783  2024-08-02 10:26:30.540839                  3
# 792  2024-08-02 10:40:51.316360                  3
# 801  2024-08-02 10:55:11.317142                  3
# 810  2024-08-02 11:09:31.711520                  3
# 819  2024-08-02 11:23:51.421372                  3
#
#                          metadata_string_acquisition_0 well_name channel  \
# 0    Metadata:\nDimensions: T(4) x XY(9) x Z(7) x λ...       D06     Red
# 9    Metadata:\nDimensions: T(4) x XY(9) x Z(7) x λ...       D06     Red
# 18   Metadata:\nDimensions: T(4) x XY(9) x Z(7) x λ...       D06     Red
# 27   Metadata:\nDimensions: T(4) x XY(9) x Z(7) x λ...       D06     Red
# 36   Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D06   TRITC
# ..                                                 ...       ...     ...
# 783  Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D06   TRITC
# 792  Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D06   TRITC
# 801  Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D06   TRITC
# 810  Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D06   TRITC
# 819  Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D06   TRITC
#
#      siRNA  replicate
# 0    ARMC5          1
# 9    ARMC5          1
# 18   ARMC5          1
# 27   ARMC5          1
# 36   ARMC5          1
# ..     ...        ...
# 783  ARMC5          1
# 792  ARMC5          1
# 801  ARMC5          1
# 810  ARMC5          1
# 819  ARMC5          1
#
# [92 rows x 18 columns]

# %%
image_metadata_annotated.query("siRNA=='ARMC5' & replicate == 1 & timepoint_id == 1")
# Out:
#      n_pixels_y  n_pixels_x          objective_name  pixel_size_microns  \
# 9          2304        2304  Plan Apo VC 20x DIC N2               0.325
# 10         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 11         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 12         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 13         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 14         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 15         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 16         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 17         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 45         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 46         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 47         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 48         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 49         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 50         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 51         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 52         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 53         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 99         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 100        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 101        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 102        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 103        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 104        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 105        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 106        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 107        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 441        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 442        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 443        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 444        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 445        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 446        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 447        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 448        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 449        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 783        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 784        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 785        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 786        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 787        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 788        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 789        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 790        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 791        2304        2304  Plan Apo VC 20x DIC N2               0.325
#
#      field_id  timepoint_id                               filename_ome_tiff  \
# 9           1             1  WellD06_ChannelRed_Scott_Seq0005_0001.ome.tiff
# 10          2             1  WellD06_ChannelRed_Scott_Seq0005_0002.ome.tiff
# 11          3             1  WellD06_ChannelRed_Scott_Seq0005_0003.ome.tiff
# 12          4             1  WellD06_ChannelRed_Scott_Seq0005_0004.ome.tiff
# 13          5             1  WellD06_ChannelRed_Scott_Seq0005_0005.ome.tiff
# 14          6             1  WellD06_ChannelRed_Scott_Seq0005_0006.ome.tiff
# 15          7             1  WellD06_ChannelRed_Scott_Seq0005_0007.ome.tiff
# 16          8             1  WellD06_ChannelRed_Scott_Seq0005_0008.ome.tiff
# 17          9             1  WellD06_ChannelRed_Scott_Seq0005_0009.ome.tiff
# 45          1             1      WellD06_ChannelTRITC_Seq0003_0001.ome.tiff
# 46          2             1      WellD06_ChannelTRITC_Seq0003_0002.ome.tiff
# 47          3             1      WellD06_ChannelTRITC_Seq0003_0003.ome.tiff
# 48          4             1      WellD06_ChannelTRITC_Seq0003_0004.ome.tiff
# 49          5             1      WellD06_ChannelTRITC_Seq0003_0005.ome.tiff
# 50          6             1      WellD06_ChannelTRITC_Seq0003_0006.ome.tiff
# 51          7             1      WellD06_ChannelTRITC_Seq0003_0007.ome.tiff
# 52          8             1      WellD06_ChannelTRITC_Seq0003_0008.ome.tiff
# 53          9             1      WellD06_ChannelTRITC_Seq0003_0009.ome.tiff
# 99          1             1      WellD06_ChannelTRITC_Seq0007_0001.ome.tiff
# 100         2             1      WellD06_ChannelTRITC_Seq0007_0002.ome.tiff
# 101         3             1      WellD06_ChannelTRITC_Seq0007_0003.ome.tiff
# 102         4             1      WellD06_ChannelTRITC_Seq0007_0004.ome.tiff
# 103         5             1      WellD06_ChannelTRITC_Seq0007_0005.ome.tiff
# 104         6             1      WellD06_ChannelTRITC_Seq0007_0006.ome.tiff
# 105         7             1      WellD06_ChannelTRITC_Seq0007_0007.ome.tiff
# 106         8             1      WellD06_ChannelTRITC_Seq0007_0008.ome.tiff
# 107         9             1      WellD06_ChannelTRITC_Seq0007_0009.ome.tiff
# 441         1             1      WellD06_ChannelTRITC_Seq0009_0001.ome.tiff
# 442         2             1      WellD06_ChannelTRITC_Seq0009_0002.ome.tiff
# 443         3             1      WellD06_ChannelTRITC_Seq0009_0003.ome.tiff
# 444         4             1      WellD06_ChannelTRITC_Seq0009_0004.ome.tiff
# 445         5             1      WellD06_ChannelTRITC_Seq0009_0005.ome.tiff
# 446         6             1      WellD06_ChannelTRITC_Seq0009_0006.ome.tiff
# 447         7             1      WellD06_ChannelTRITC_Seq0009_0007.ome.tiff
# 448         8             1      WellD06_ChannelTRITC_Seq0009_0008.ome.tiff
# 449         9             1      WellD06_ChannelTRITC_Seq0009_0009.ome.tiff
# 783         1             1      WellD06_ChannelTRITC_Seq0001_0001.ome.tiff
# 784         2             1      WellD06_ChannelTRITC_Seq0001_0002.ome.tiff
# 785         3             1      WellD06_ChannelTRITC_Seq0001_0003.ome.tiff
# 786         4             1      WellD06_ChannelTRITC_Seq0001_0004.ome.tiff
# 787         5             1      WellD06_ChannelTRITC_Seq0001_0005.ome.tiff
# 788         6             1      WellD06_ChannelTRITC_Seq0001_0006.ome.tiff
# 789         7             1      WellD06_ChannelTRITC_Seq0001_0007.ome.tiff
# 442  ARMC5          1
# 443  ARMC5          1
# 444  ARMC5          1
# 445  ARMC5          1
# 446  ARMC5          1
# 447  ARMC5          1
# 448  ARMC5          1
# 449  ARMC5          1
# 783  ARMC5          1
# 784  ARMC5          1
# 785  ARMC5          1
# 786  ARMC5          1
# 787  ARMC5          1
# 788  ARMC5          1
# 789  ARMC5          1
# 790  ARMC5          1
# 791  ARMC5          1

# %% [markdown]
# ## Save Examples

# %%
import random
random.seed(10)
example_images = image_metadata_annotated.query("channel=='TRITC'").groupby(['siRNA']).apply(pd.DataFrame.sample,n=2)

# %%
example_images
# Out:
#                 n_pixels_y  n_pixels_x          objective_name  \
# siRNA
# ARMC5     1064        2304        2304  Plan Apo VC 20x DIC N2
#           981         2304        2304  Plan Apo VC 20x DIC N2
# Scrambled 2552        2304        2304  Plan Apo VC 20x DIC N2
#           2895        2304        2304  Plan Apo VC 20x DIC N2
#
#                 pixel_size_microns  field_id  timepoint_id  \
# siRNA
# ARMC5     1064               0.325         3            16
#           981                0.325         1             7
# Scrambled 2552               0.325         6             3
#           2895               0.325         7            35
#
#                                          filename_ome_tiff  \
# siRNA
# ARMC5     1064  WellE05_ChannelTRITC_Seq0016_0003.ome.tiff
#           981   WellE05_ChannelTRITC_Seq0016_0001.ome.tiff
# Scrambled 2552  WellE06_ChannelTRITC_Seq0011_0006.ome.tiff
#           2895  WellE06_ChannelTRITC_Seq0019_0007.ome.tiff
#
#                 acquisition_time_rel  stage_y_abs   stage_x_abs  stage_z_n  \
# siRNA
# ARMC5     1064          60937.568508  3371.800000  10614.600000          7
#           981           53161.183196  3382.742857  12112.400000          7
# Scrambled 2552          42592.469372  4126.085714   3163.914286          7
#           2895          77546.771691  4874.528571   5958.514286          7
#
#                       acquisition_time_abs  standard_field_id  \
# siRNA
# ARMC5     1064  2024-09-02 23:50:59.568508                  1
#           981   2024-09-02 21:41:23.183196                  3
# Scrambled 2552  2024-08-03 09:06:02.469372                  6
#           2895  2024-09-03 04:31:04.771691                  9
#
#                                     metadata_string_acquisition_0 well_name  \
# siRNA
# ARMC5     1064  Metadata:\nDimensions: T(38) x XY(9) x Z(7) x ...       E05
#           981   Metadata:\nDimensions: T(38) x XY(9) x Z(7) x ...       E05
# Scrambled 2552  Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       E06
#           2895  Metadata:\nDimensions: T(38) x XY(9) x Z(7) x ...       E06
#
#                channel      siRNA  replicate
# siRNA
# ARMC5     1064   TRITC      ARMC5          2
#           981    TRITC      ARMC5          2
# Scrambled 2552   TRITC  Scrambled          2
#           2895   TRITC  Scrambled          2

# %% [markdown]
# ## Save examples for training nuclear segmentation model

# %% [markdown]
# Here we crop images before saving to remove vignetting artefact and ensure training data is appropriate

# %%
training_dir = Path(image_dir).parent / 'TRAINING'
if not training_dir.exists(): 
    training_dir.mkdir()

# %%
for index, row in example_images.iterrows():
    aics_image = AICSImage(Path(image_dir) / row["filename_ome_tiff"], reader=readers.ome_tiff_reader.OmeTiffReader)
    mCherry_array = aics_image.get_image_data('YX',Z=0,C=0,T=row["timepoint_id"])
    mCherry_image = illumination_correction.correct(AICSImage(mCherry_array[np.newaxis,np.newaxis,np.newaxis,:,:]))
    # crop 500 pixels from left edge
    mCherry_image = AICSImage(mCherry_image.get_image_data('YX',Z=0,C=0,T=0)[np.newaxis,np.newaxis,np.newaxis,:,500:])
    mCherry_image.save(str(training_dir / row["filename_ome_tiff"]))

# %% [markdown]
# Get also the lowest intensity images (immediately after bleach to ensure these are properly segmented

# %%
image_metadata_annotated.query("channel=='TRITC' & replicate == 1 & timepoint_id == 1 & field_id == 1")
# Out:
#       n_pixels_y  n_pixels_x          objective_name  pixel_size_microns  \
# 45          2304        2304  Plan Apo VC 20x DIC N2               0.325
# 99          2304        2304  Plan Apo VC 20x DIC N2               0.325
# 441         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 783         2304        2304  Plan Apo VC 20x DIC N2               0.325
# 1701        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 2043        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 2097        2304        2304  Plan Apo VC 20x DIC N2               0.325
# 2439        2304        2304  Plan Apo VC 20x DIC N2               0.325
#
#       field_id  timepoint_id                           filename_ome_tiff  \
# 45           1             1  WellD06_ChannelTRITC_Seq0003_0001.ome.tiff
# 99           1             1  WellD06_ChannelTRITC_Seq0007_0001.ome.tiff
# 441          1             1  WellD06_ChannelTRITC_Seq0009_0001.ome.tiff
# 783          1             1  WellD06_ChannelTRITC_Seq0001_0001.ome.tiff
# 1701         1             1  WellD05_ChannelTRITC_Seq0008_0001.ome.tiff
# 2043         1             1  WellD05_ChannelTRITC_Seq0000_0001.ome.tiff
# 2097         1             1  WellD05_ChannelTRITC_Seq0006_0001.ome.tiff
# 2439         1             1  WellD05_ChannelTRITC_Seq0002_0001.ome.tiff
#
#       acquisition_time_rel  stage_y_abs   stage_x_abs  stage_z_n  \
# 45             1061.161528 -5617.157143   6004.400000          7
# 99             8134.297253 -5617.271429   3204.714286          7
# 441            8265.229409 -5617.185714   6004.300000          7
# 783             930.540839 -5616.985714   3204.614286          7
# 1701           8199.607210 -5611.357143  14947.100000          7
# 2043            865.631245 -5611.242857  12147.385714          7
# 2097           8069.361694 -5611.328571  12147.400000          7
# 2439            995.638590 -5611.371429  14947.200000          7
#
#             acquisition_time_abs  standard_field_id  \
# 45    2024-08-02 10:30:52.161528                  3
# 99    2024-08-02 22:05:33.297253                  3
# 441   2024-08-02 22:09:55.229409                  3
# 783   2024-08-02 10:26:30.540839                  3
# 1701  2024-08-02 22:07:43.607210                  3
# 2043  2024-08-02 10:24:20.631245                  3
# 2097  2024-08-02 22:03:24.361694                  3
# 2439  2024-08-02 10:28:41.638590                  3
#
#                           metadata_string_acquisition_0 well_name channel  \
# 45    Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D06   TRITC
# 99    Metadata:\nDimensions: T(38) x XY(9) x Z(7) x ...       D06   TRITC
# 441   Metadata:\nDimensions: T(38) x XY(9) x Z(7) x ...       D06   TRITC
# 783   Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D06   TRITC
# 1701  Metadata:\nDimensions: T(38) x XY(9) x Z(7) x ...       D05   TRITC
# 2043  Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D05   TRITC
# 2097  Metadata:\nDimensions: T(38) x XY(9) x Z(7) x ...       D05   TRITC
# 2439  Metadata:\nDimensions: T(6) x XY(9) x Z(7) x λ...       D05   TRITC
#
#           siRNA  replicate
# 45        ARMC5          1
# 99        ARMC5          1
# 441       ARMC5          1
# 783       ARMC5          1
# 1701  Scrambled          1
# 2043  Scrambled          1
# 2097  Scrambled          1
# 2439  Scrambled          1

# %%
after_bleach_images = ["WellD05_ChannelTRITC_Seq0006_0001.ome.tiff", "WellD06_ChannelTRITC_Seq0007_0001.ome.tiff"]
for f in after_bleach_images:
    aics_image = AICSImage(Path(image_dir) / f, reader=readers.ome_tiff_reader.OmeTiffReader)
    mCherry_array = aics_image.get_image_data('YX',Z=0,C=0,T=0)
    mCherry_image = illumination_correction.correct(AICSImage(mCherry_array[np.newaxis,np.newaxis,np.newaxis,:,:]))
    # crop 500 pixels from left edge
    mCherry_image = AICSImage(mCherry_image.get_image_data('YX',Z=0,C=0,T=0)[np.newaxis,np.newaxis,np.newaxis,:,500:])
    mCherry_image.save(str(training_dir / f))

# %% [markdown]
# ## Export images for example bleach-chase movie

# %%
movie_dir = Path(image_dir).parent / 'MOVIE'
if not movie_dir.exists(): 
    movie_dir.mkdir()

pre_bleach_images = ["WellD05_ChannelTRITC_Seq0000_0005.ome.tiff", "WellD06_ChannelTRITC_Seq0001_0005.ome.tiff"]
after_bleach_images = ["WellD05_ChannelTRITC_Seq0006_0005.ome.tiff", "WellD06_ChannelTRITC_Seq0007_0005.ome.tiff"]
for f in (pre_bleach_images + after_bleach_images):
    aics_image = AICSImage(Path(image_dir) / f, reader=readers.ome_tiff_reader.OmeTiffReader)
    mCherry_array = aics_image.get_image_data('TYX',Z=0,C=0)
    mCherry_image = illumination_correction.correct(AICSImage(mCherry_array[:,np.newaxis,np.newaxis,:,:]))
    # crop 500 pixels from left edge, 100 pixels from right edge and 300 from top and bottom
    mCherry_image = AICSImage(mCherry_image.get_image_data('TYX',Z=0,C=0)[:,np.newaxis,np.newaxis,300:1748,500:1948])
    mCherry_image.save(str(movie_dir / f))

# %%
movie_dir = Path(image_dir).parent / 'MOVIE'
if not movie_dir.exists(): 
    movie_dir.mkdir()

pre_bleach_images = ["WellD05_ChannelTRITC_Seq0002_0005.ome.tiff", "WellD06_ChannelTRITC_Seq0003_0005.ome.tiff"]
after_bleach_images = ["WellD05_ChannelTRITC_Seq0008_0005.ome.tiff", "WellD06_ChannelTRITC_Seq0009_0005.ome.tiff"]
for f in (pre_bleach_images + after_bleach_images):
    aics_image = AICSImage(Path(image_dir) / f, reader=readers.ome_tiff_reader.OmeTiffReader)
    mCherry_array = aics_image.get_image_data('TYX',Z=0,C=0)
    mCherry_image = illumination_correction.correct(AICSImage(mCherry_array[:,np.newaxis,np.newaxis,:,:]))
    # crop 500 pixels from left edge, 100 pixels from right edge and 300 from top and bottom
    mCherry_image = AICSImage(mCherry_image.get_image_data('TYX',Z=0,C=0)[:,np.newaxis,np.newaxis,300:1748,500:1948])
    mCherry_image.save(str(movie_dir / f))
